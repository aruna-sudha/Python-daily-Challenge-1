# %%
student_name = "Arun"
student_age = 14
favourite_subjects = ["Math", "Science", "English"]

# %%
print("Student Profile")
print(f"Name: {student_name}")
print(f"Age: {student_age}")
print("Favourite Subjects:", ", ".join(favourite_subjects))
# Out:
# Student Profile
# Name: Arun
# Age: 14
# Favourite Subjects: Math, Science, English

# %%
new_subject = input("\nEnter another favourite subject to add: ")

favourite_subjects.append(new_subject)
# Out:
# Enter another favourite subject to add: Computer

# %%
print(f"Updated Favourite Subjects: {favourite_subjects}")
# Out:
# Updated Favourite Subjects: ['Math', 'Science', 'English', ' Computer', 'Computer']
